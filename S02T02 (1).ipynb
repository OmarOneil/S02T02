# %% [markdown]
# # Exercici 1
# Crea un np.array d'una dimensió, que inclogui l'almenys 8 nombres sencers, data type int64. Mostra la dimensió i la forma de la matriu. .

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# Crear una matrice de una demension

a = np.array([1,7,5,9,0,8,4,11], ndmin=1, dtype = np.int64 )
a
n = len(a)

# %%
#show the data type
a.dtype
# Out:
# dtype('int64')

# %%
#Show the dimension 
a.ndim
# Out:
# 1

# %%
# Show the shape
a.shape
# Out:
# (8,)

# %%
# Sort  
sorted(a)
# Out:
# [0, 1, 4, 5, 7, 8, 9, 11]

# %% [markdown]
# # Exercici 2
# De la matriu de l'exercici 1, calcula el valor mitjà dels valors introduïts i resta la mitjana resultant de cada un dels valors de la matriu.

# %%
# geting the mean
np.mean(a)
# Out:
# 5.625

# %%
#getting the median
np.median(a)
# Out:
# 6.0

# %%
#subtract the median from each of the values in the matrix
a - np.median(a)
# Out:
# array([-5.,  1., -1.,  3., -6.,  2., -2.,  5.])

# %% [markdown]
# # Exercici 3
# Crea una matriu bidimensional amb una forma de 5 x 5. Extreu el valor màxim de la matriu, i els valors màxims de cadascun dels seus eixos.

# %%
#Create a two-dimensional array with a 5 x 5 shape
b = np.random.randint(1,101,size=(2,5)) 
b
# Out:
# array([[82, 81,  4, 82, 86],
#        [16, 16,  3, 35, 86]])

# %%
#maximum value in the array
np.amax(b)
# Out:
# 86

# %%
# the maximum values axis 0
np.amax(b, axis=0)
# Out:
# array([82, 81,  4, 82, 86])

# %%
# the maximum values axis 1
np.amax(b, axis=1)
# Out:
# array([86, 86])

# %% [markdown]
# # Exercici 4
# Mostreu-me amb exemples de diferents matrius, la regla fonamental de Broadcasting que diu : "les matrius es poden transmetre / broadcast si les seves dimensions coincideixen o si una de les matrius té una mida d'1".

# %%
# 2 examples of a 2 matrixis

x = np.array([[0],[1],[2]])
y = np.array([[3,4,5]])

print(x)
print(y)
# Out:
# [[0]
#  [1]
#  [2]]
# [[3 4 5]]

# %%
x+y
# Out:
# array([[3, 4, 5],
#        [4, 5, 6],
#        [5, 6, 7]])

# %%
x.shape
# Out:
# (3, 1)

# %%
y.shape
# Out:
# (1, 3)

# %% [markdown]
#  Examples for compatibility and not :
#
#  x.shape == (2,3)
#
#  y.shape == (2,3) #compatible \
#  y.shape == (2,1) #compatible \
#  y.shape == (1,3) #compatible \
#  y.shape == (3,) #compatible
#
#  y.shape == (3,2) #NOT compatible \
#  y.shape == (2,) #Not compatible
#
#  Shape Compatibility Rules
#
# 1. If x, y have a different number of dimensions, prepend 1's to the shape of the shorter.
# 2. Any axis of length 1 can be repeated (broadcast) to the length of the other vector's length
#    in that axis
# 3. All other axes must have matching lengths.

# %%
# Create 2 matrix
matrix1 = np.arange(1, 7).reshape(2,3)
matrix2 = np.arange(3, 9).reshape(2,3)

# %%
matrix1
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
matrix2
# Out:
# array([[3, 4, 5],
#        [6, 7, 8]])

# %%
#multiplication
matrix1*matrix2
# Out:
# array([[ 3,  8, 15],
#        [24, 35, 48]])

# %%
#Changing the shape of matrix2
matrix2 = np.arange(3,5).reshape(2,1)

# %%
matrix2
# Out:
# array([[3],
#        [4]])

# %%
# division
matrix1/matrix2
# Out:
# array([[0.33333333, 0.66666667, 1.        ],
#        [1.        , 1.25      , 1.5       ]])

# %%
#subtraction
matrix1-matrix2
# Out:
# array([[-2, -1,  0],
#        [ 0,  1,  2]])

# %% [markdown]
# #  Exercici 5
# Utilitza la Indexació per extreure els valors d'una columna i una fila de la matriu. I suma els seus valors.

# %%
# extract column from indexing
column1 = matrix1[: 2]
column1
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
#extract row
row1 =  matrix1[1, :]
row1
# Out:
# array([4, 5, 6])

# %%
#Sum column = row
column1 + row1
# Out:
# array([[ 5,  7,  9],
#        [ 8, 10, 12]])

# %% [markdown]
# #  Exercici 6
# Mask la matriu anterior, realitzeu un càlcul booleà vectoritzat, agafant cada element i comprovant si es divideix uniformement per quatre.

# %%
#create a boolean mask
mask = (matrix1 % 4 == 0)
mask
# Out:
# array([[False, False, False],
#        [ True, False, False]])

# %% [markdown]
# # Exercici 7
# A continuació, utilitzeu aquesta màscara per indexar a la matriu de números original. Això fa que la matriu perdi la seva forma original, reduint-la a una dimensió, però encara obteniu les dades que esteu cercant.

# %%
#apply the mask to get just the truw value in the mask
matrix1[mask]
# Out:
# array([4])

# %% [markdown]
# #  Exercici 8
# Mostreu-me a veure que passa quan eliminem el canal G Verd o B Blau.
#
# Mostreu-me a veure què passa quan eliminem el canal G Verd o B Blau. Hauries d'utilitzar la indexació per seleccionar el canal que voleu anul·lar.
#
# Utilitzar el mètode, mpimg.imsave () de la llibreria importada, per guardar les imatges modificades i que haureu de pujar al vostre repositori a github.

# %%
#getting the image 
img = mpimg.imread('image1.jpeg')

# %%
#Image shape
img.shape
# Out:
# (339, 509, 3)

# %%
# the data type
img.dtype
# Out:
# dtype('uint8')

# %%
#show the image using plot
imgplot = plt.imshow(img)

# %%
#copy the image
new_img = img.copy()

# %%
# taking 2 colors out
new_img[:,:,1] = 0

# %%
#show the new image
imgplot = plt.imshow(new_img)

# %%
fig = plt.figure()
ax = fig.subplots()
#transperency 
f = ax.imshow(img[:,:,1], alpha = 0.5)
plt.show()

# %%
#Chainging color with the color map and a color bar
fig = plt.figure()
ax = fig.subplots()
#applying a Gray color map
f = ax.imshow(img[:,:,1], alpha = 1, cmap = 'gray')
#adding a color bar
fig.colorbar(f)
#save the pictures
plt.savefig("ximag.jpeg", bbox_inches = "tight")
plt.show()

# %%
# save a image using mpimg.imsave()
plt.imsave("new_image.jpeg", new_img)
